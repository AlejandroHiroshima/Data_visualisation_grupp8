# %%
import pandas as pd
import duckdb as db
import matplotlib.pyplot as plt

plt.style.use('Style/base.mplstyle')

df_sökande= pd.read_csv(
    "../data/2024_kurser/Ansökande_2020-2024.csv",
    encoding="latin-1"
)
df = pd.read_excel("../data/2024_kurser/inkomna-ansokningar-2024-for-kurser.xlsx")

df_sökande.head()
# Out:
#       kön utbildningsområde MYH     region (hemlän) utbildningens studietakt  \
# 0  totalt               Data/It      Stockholms län                   Heltid
# 1  totalt               Data/It         Uppsala län                   Heltid
# 2  totalt               Data/It   Södermanlands län                   Heltid
# 3  totalt               Data/It   Östergötlands län                   Heltid
# 4  totalt               Data/It      Jönköpings län                   Heltid
#
#    Antal ansökningar 2020  Antal ansökningar 2021  Antal ansökningar 2022  \
# 0                     399                     230                      55
# 1                      28                      12                      11
# 2                      19                      17                       6
# 3                      13                      34                       5
# 4                      15                      13                       5
#
#    Antal ansökningar 2023  Antal ansökningar 2024  Antal sökande 2020  \
# 0                     463                     244                 375
# 1                      35                      22                  26
# 2                      21                      15                  16
# 3                      35                      21                  11
# 4                      20                       7                  14
#
#    Antal sökande 2021  Antal sökande 2022  Antal sökande 2023  \
# 0                 189                  54                 413
# 1                  10                   9                  34
# 2                  14                   5                  18
# 3                  26                   5                  30
# 4                  11                   5                  19
#
#    Antal sökande 2024
# 0                 229
# 1                  22
# 2                  13
# 3                  21
# 4                   6

# %%
df_top_omraden = db.query(
    """
    SELECT 
      "Sökt utbildningsområde" AS Utbildningsområde,
      SUM("Sökt antal platser 2024") AS År2024,
      SUM("Sökt antal platser 2025") AS År2025,
      SUM("Sökt antal platser 2025") - SUM("Sökt antal platser 2024") AS Tillväxt
    FROM df
    GROUP BY "Sökt utbildningsområde"
    ORDER BY Tillväxt DESC
    LIMIT 10
    """
).df().set_index("Utbildningsområde")

# %%
import constant

ax = df_top_omraden[["År2024", "År2025"]].plot(
    kind="barh",
    figsize=(12, 6),
    color=[constant.DARK_ORANGE, constant.SADDLEBROWN],
)

ax.set_title("VÄXANDE UTBILDNINGSOMRÅDE I REGIONEN", loc="left", pad=20)
ax.set_xlabel("ANTAL SÖKANDE FÖR SKOLOR", loc="left")
ax.set_ylabel("UTBILDNINGSOMRÅDE", rotation= 0)
ax.yaxis.set_label_coords(-0.12, 1)

ax.patch.set_facecolor(constant.WHEAT_BROWN)
ax.invert_yaxis()
ax.legend().remove()
