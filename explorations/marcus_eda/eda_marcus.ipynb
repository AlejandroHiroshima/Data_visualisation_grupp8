# %%
# import numpy as np

# bevilade_avslag.sort_values(by= "antal_avslag", inplace= True)
# ax = bevilade_avslag.plot(kind="barh", figsize=(12, 6))

# # Creating side stacked bar 
# length = np.arange(len(bevilade_avslag["Sökt utbildningsområde"]))
# ax.barh(
#     length, bevilade_avslag["antal_avslag"], label="Ansökt", color="#50628e"
# )
# ax.barh(
#     length,
#     bevilade_avslag["Totalt antal beviljade platser"],
#     left=bevilade_avslag["antal_avslag"],
#     label="Avslag",
#     color= "#051f5e"
# )


# # clutter
# ax.legend().remove()
# ax.tick_params("y", length= 0)
# ax.spines[["top", "right"]].set_visible(False)

# # Description and title 
# ax.set_yticklabels(bevilade_avslag["Sökt utbildningsområde"])
# ax.set_title("Antal avslag och antal bevilade platser för kurser 2024 och 2025", pad= 20)
# ax.set_ylabel("UTBILDNINGSOMRÅDE", loc= "top", rotation= 0, fontsize= 12)
# ax.yaxis.set_label_coords(0, 1)
# ax.set_xlabel("TOTAL AMOUNT", loc= "left", fontsize= 12)


# # Annotation
# rect1 = ax.patches[0] # Första stapalen (Data/IT)
# rect2 = ax.patches[2] # Andra staplen (Ekonomi, admiminstration och försäljning)


# ax.annotate(
#     "Avslag för ansökta platser",
#     xy= (rect1.get_width() + 5000, rect1.get_y() + 8.5),
#     ha="center",
#     va="center",
#     arrowprops= dict(arrowstyle= "->", linewidth= 0.8, connectionstyle= "arc3, rad=-.1 "),
#     xytext = (rect1.get_height() +10000, rect1.get_y() + 6)
    
# )

# ax.annotate(
#     "Beviljade ansökta platser",
#     xy= (rect2.get_height() +15000, rect2.get_y() + 9.5),
#     ha= "center",
#     va= "center",
#     arrowprops=dict(facecolor= "black", shrink= 0.02, width= 0.5),
#     xytext= (rect2.get_height() + 15000, rect2.get_y() + 6)
# )


# fig.tight_layout()
# fig.show()

# %%
import pandas as pd
from pathlib import Path



df_program_2024 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2024.xlsx", sheet_name= "Tabell 3", skiprows=5)
df_program_2023 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2023.xlsx", sheet_name= "Tabell 3", skiprows=5)
df_program_2022 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2022.xlsx", sheet_name= "Tabell 4")
df_program_2021 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2021.xlsx", sheet_name= "Tabell 4")
df_program_2020 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2020.xlsx", sheet_name= "Tabell 4")


df_program_2024.head()

# %%
df_kurser_2020_april = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/Beviljade-korta-utb-kurser-kurspaket-YH-april-2020-1.xlsx")
df_kurser_2020_juli = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/Beviljade-korta-utb-kurser-kurspaket-YH-juli-2020-2.xlsx")
df_kurser_2021_lista = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/inkomna-ansokningar-juni-2021-for-korta-utbildningar-kurser-och-kurspaket.xlsx")
df_kurser_2021_beviljade = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/resultat-juni-2021-for-korta-utbildningar-kurser-och-kurspaket.xlsx")
df_kurser_2022 = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/resultat-2022-for-kurser-inom-yh.xlsx")
df_kurser_2023 = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/resultat-2023-for-kurser-inom-yh.xlsx")
df_kurser_2024 = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/resultat-2024-for-kurser-inom-yh.xlsx")


df_kurser_2021_beviljade["Beslut"] = "Beviljad"

# %%
df_kurser_2024.columns

# %%
def reading_file():
       
    
    dict_courses = {}
    
    
    df_kurser_2024 = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/resultat-2024-for-kurser-inom-yh.xlsx")
    df_kurser_2024.drop("Antal beviljade platser start och slut 2024", axis= 1, inplace=True)
    dict_courses[2024] = df_kurser_2024
    
    df_kurser_2023 = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/resultat-2023-for-kurser-inom-yh.xlsx")
    dict_courses[2023] = df_kurser_2023
            
    df_kurser_2022 = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/resultat-2022-for-kurser-inom-yh.xlsx")
    dict_courses[2022] = df_kurser_2022
    
    df_kurser_2021_lista = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/inkomna-ansokningar-juni-2021-for-korta-utbildningar-kurser-och-kurspaket.xlsx")
    df_kurser_2021_beviljade = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/resultat-juni-2021-for-korta-utbildningar-kurser-och-kurspaket.xlsx")
    df_kurser_2021 = pd.concat([df_kurser_2021_lista, df_kurser_2021_beviljade])
    if "Beslut" in df_kurser_2021:
                
        df_kurser_2021["Beslut"] = df_kurser_2021["Beslut"].fillna("Avslag")
        dict_courses[2021] = df_kurser_2021
    else:
        dict_courses[2021] = df_kurser_2021
    
            
    df_kurser_2020_april = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/Beviljade-korta-utb-kurser-kurspaket-YH-april-2020-1.xlsx")
    df_kurser_2020_juli = pd.read_excel("../../data/anordnare_resultat_kurser_2020-2024/Beviljade-korta-utb-kurser-kurspaket-YH-juli-2020-2.xlsx")
    df_kurser_2020 = pd.concat([df_kurser_2020_april, df_kurser_2020_juli])
    dict_courses[2020] = df_kurser_2020
            
            
    return dict_courses
            
dict_c = reading_file()

dict_c.keys()

# %%
def reading_file_programs():
    
    dict_programs = {}
    
    df_program_2024 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2024.xlsx", sheet_name= "Tabell 3", skiprows=5)
    dict_programs["2024"] = df_program_2024 
    
    df_program_2023 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2023.xlsx", sheet_name= "Tabell 3", skiprows=5)
    dict_programs[2023] = df_program_2023
    
    df_program_2022 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2022.xlsx", sheet_name= "Tabell 3")
    dict_programs[2022] = df_program_2022
    
    df_program_2021 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2021.xlsx", sheet_name= "Tabell 3")
    dict_programs[2021] = df_program_2021
    
    df_program_2020 = pd.read_excel("../../data/program_2020-2024/resultat-ansokningsomgang-2020.xlsx", sheet_name= "Tabell 3")
    dict_programs[2020] = df_program_2020


    return dict_programs

dict_p = reading_file_programs()
    
dict_p.keys()

# %%
df_kurser_2020 = pd.concat([df_kurser_2020_april, df_kurser_2020_juli])
df_kurser_2021 = pd.concat([df_kurser_2021_lista, df_kurser_2021_beviljade])
    
df_kurser_2021["Beslut"] = df_kurser_2021["Beslut"].fillna("Avslag")

# %%
df_kurser_2020 = pd.concat([df_kurser_2020_april, df_kurser_2020_juli])
df_kurser_2021 = pd.concat([df_kurser_2021_lista, df_kurser_2021_beviljade])

# %%
df_kurser_2021["Beslut"] = df_kurser_2021["Beslut"].fillna("Avslag")

df_kurser_2021[df_kurser_2021["Beslut"] == "Beviljad"]

# %%
df_kurser_2024.query("Beslut == 'Beviljad'")

# %%
global_dict_programs = {
    2024: "df_2024_program",
    2023: "df_2023_program",
    2022: "df_2022_program",
    2021: "df_2021_program",
    2020: "df_2020_program" 
}

year = 2021
global_dict_programs[year]

# %%
df_program_2023.columns

# %%
def filter_data_platser_program(df):
    df_summary = df.groupby("Utbildningsanordnare administrativ enhet")[["Sökta platser totalt", "Beviljade platser totalt"]].sum().reset_index()
    df_summary
    
    return df_summary

# %%
def count_perc_program(df_summary):
    
    df_perc_count = df_summary["Beviljade platser totalt"] / df_summary["Sökta platser totalt"] * 100
    
    return df_perc_count


count = filter_data_platser_program(df_program_2024)
count_perc_program(count)

# %%
be = df_kurser_2024[df_kurser_2024["Beslut"] == "Beviljad"].groupby("Anordnare namn")["Totalt antal beviljade platser"].sum()

# %%
df_kurser_2024.query("Beslut == 'Beviljad'")
# Out:
#       Diarienummer    Beslut                         Anordnare namn  \
# 7    MYH 2024/1009  Beviljad     Plushögskolan AB - Affärshögskolan
# 8    MYH 2024/1010  Beviljad        IHM Business School AB Göteborg
# 11   MYH 2024/1016  Beviljad  Plushögskolan AB - Vårdyrkeshögskolan
# 12   MYH 2024/1017  Beviljad   Hyper Island Program AB - Karlskrona
# 13   MYH 2024/1018  Beviljad     Plushögskolan AB - Affärshögskolan
# ..             ...       ...                                    ...
# 872   MYH 2024/990  Beviljad               Företagsuniversitetet AB
# 873   MYH 2024/993  Beviljad                                INSU AB
# 874   MYH 2024/994  Beviljad               Företagsuniversitetet AB
# 875   MYH 2024/995  Beviljad    Hyper Island Program AB - Stockholm
# 878   MYH 2024/998  Beviljad                        Campus Nyköping
#
#                                        Utbildningsnamn  \
# 7                     Strategisk hållbarhetsutveckling
# ...
