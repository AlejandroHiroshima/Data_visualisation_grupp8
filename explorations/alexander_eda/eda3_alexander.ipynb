# %% [markdown]
# # Exploration of the dataset for the task "beräkna fram hur mycket statsbidrag en beviljad utbildning får."

# %%
import pandas as pd
path = "../../data/statliga_bidrag/ek_4_utbet_arsplatser_utbomr.xlsx"
df = pd.read_excel(path, skiprows=5, skipfooter=4)
index = df.columns[0]
df = df.set_index(index)
df.head()
# Out:
#                                                 2012         2013  \
# Utbildningsområde
# Data/IT                                  1737.481912  2205.505909
# Ekonomi, administration och försäljning  6440.213254  7155.296738
# Friskvård och kroppsvård                  223.749143   215.499254
# Hotell, restaurang och turism            1362.037288  1385.183165
# Hälso- och sjukvård samt socialt arbete  2149.400705  2359.066355
#
#                                                 2014         2015  \
# Utbildningsområde
# Data/IT                                  2556.642979  3192.549089
# Ekonomi, administration och försäljning  7441.238585  7424.231141
# Friskvård och kroppsvård                  214.332199   202.291124
# Hotell, restaurang och turism            1445.853403  1460.825305
# Hälso- och sjukvård samt socialt arbete  2637.583012  3052.793098
#
#                                                 2016         2017  \
# Utbildningsområde
# ...

# %%
df.loc['Hotell, restaurang och turism', int('2020')].round(1)
# Out:
# np.float64(1770.1)

# %%
df.describe()
# Out:
#                2012          2013          2014          2015          2016  \
# count     16.000000     16.000000     16.000000     16.000000     16.000000
# mean    2704.774897   3026.283180   3167.526143   3376.741798   3408.771049
# std     5311.352920   5944.451019   6223.459867   6610.824554   6646.553268
# min      103.833227    168.416654    169.666372    129.749949    125.833308
# 25%      222.353412    215.040950    295.645064    272.759958    310.124899
# 50%     1124.975170   1102.957234   1078.285341   1119.340717   1180.919996
# 75%     2187.854921   2473.964917   2704.089803   3153.171253   3505.456603
# max    21638.199175  24210.265437  25340.209147  27013.934384  27270.168390
#
#                2017          2018          2019          2020          2021  \
# count     16.000000     16.000000     16.000000     16.000000     16.000000
# mean    3550.014703   3882.312521   4441.862972   5310.498031   6220.237449
# ...

# %%
df.dtypes
# Out:
# 2012    float64
# 2013    float64
# 2014    float64
# 2015    float64
# 2016    float64
# 2017    float64
# 2018    float64
# 2019    float64
# 2020    float64
# 2021    float64
# 2022    float64
# 2023    float64
# 2024    float64
# dtype: object

# %%
for i in df.index:
    print(i)
# Out:
# Data/IT
# Ekonomi, administration och försäljning
# Friskvård och kroppsvård
# Hotell, restaurang och turism
# Hälso- och sjukvård samt socialt arbete
# Journalistik och information
# Juridik
# Kultur, media och design
# Lantbruk, djurvård, trädgård, skog och fiske
# Pedagogik och undervisning
# Samhällsbyggnad och byggteknik
# Säkerhetstjänster
# Teknik och tillverkning
# Transporttjänster
# Övrigt
# Totalt

# %%
def func(area, year):
    area_cleaned = area.strip()
    price_year = df.loc[area_cleaned, int(year)]
    price_year = price_year * schablon_moms[area_cleaned]
    print(price_year)

func('Hotell, restaurang och turism', '2020')
# Out:
# 121609228.06611814

# %%
schablon_moms = {
    "Data/IT": 74100,
    "Ekonomi, administration och försäljning": 66600,
    "Friskvård och kroppsvård": 79200,
    "Hotell, restaurang och turism":68700,
    "Hälso- och sjukvård samt socialt arbete": 7100,
    "Journalistik och information": 70600,
    "Juridik": 64100,
    "Kultur, media och design": 89400,
    "Lantbruk, djurvård, trädgård, skog och fiske":116700,
    "Pedagogik och undervisning": 75500,
    "Samhällsbyggnad och byggteknik": 74600,
    "Säkerhetstjänster": 66800,
    "Teknik och tillverkning": 91000,
    "Transporttjänster": 85200
}

schablon_moms["Data/IT"]
# Out:
# 74100
